# %% [markdown]
# # Data Analysis & Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Name": ["Amit","Riya","John","Sara","David","Anu","Rahul","Meena","Tom","Neha",
             "Arjun","Pooja","Vikram","Nisha","Kiran","Sneha","Rohit","Divya","Sam","Liya"],
    "Age": [25,30,28,35,40,29,32,27,45,31,26,33,38,36,41,24,37,34,39,28],
    "Department": ["HR","IT","Finance","IT","HR","Finance","IT","HR","Finance","IT",
                   "HR","Finance","IT","HR","Finance","IT","HR","Finance","IT","HR"],
    "Salary": [30000,50000,45000,60000,55000,40000,52000,31000,48000,51000,
               33000,47000,62000,58000,49000,53000,57000,46000,61000,35000],
    "Experience": [2,5,4,7,10,3,6,2,8,5,3,6,9,7,8,4,7,6,9,2],
    "PerformanceScore": [70,85,80,90,88,75,82,68,86,84,72,81,91,87,83,79,89,78,92,74]
}

df = pd.DataFrame(data)
df

# %%
salary_array = df["Salary"].values
exp_array = df["Experience"].values

np.mean(salary_array), np.median(salary_array), np.std(salary_array), np.max(exp_array), np.min(exp_array)

# %%
normalized_salary = (salary_array - np.mean(salary_array)) / np.std(salary_array)
normalized_salary

# %%
df.head()

# %%
df.describe()

# %%
df.groupby("Department")["Salary"].mean()

# %%
df.loc[df["PerformanceScore"].idxmax()]

# %%
df["Salary_After_Bonus"] = df["Salary"] * 1.10
df

# %%
df.groupby("Department")["Salary"].mean().plot(kind="bar")
plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.legend(["Salary"])
plt.show()

# %%
plt.plot(df["Age"], df["Salary"], marker='o')
plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.legend(["Salary"])
plt.show()

# %%
dept_count = df["Department"].value_counts()
plt.pie(dept_count, labels=dept_count.index, autopct='%1.1f%%')
plt.title("Department Distribution")
plt.show()

# %%
plt.hist(df["Salary"], bins=10)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()
